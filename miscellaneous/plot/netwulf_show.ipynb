# %%
import networkx as nx
from netwulf import visualize

print(f'networkx version : {nx.__version__}')
# Out:
# networkx version : 2.5

# %%
N = 100
M = N * 10

G = nx.gnm_random_graph(N, M, seed=42)
data = visualize(G,plot_in_cell_below=True)
